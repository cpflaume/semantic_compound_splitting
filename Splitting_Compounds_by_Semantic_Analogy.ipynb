# %%
import demo
# Out:
# Loading models...
# Loaded!

# %%
demo.draw_lattice("Hauptbahnhof")

# %%
demo.draw_lattice("Volkswirtschaftslehre")

# %%
demo.draw_lattice("Hausfrau")

# %%
demo.draw_lattice("Hauptbahnhof")

# %%
demo.draw_viterbi("Volkswirtschaftslehre")

# %%
demo.draw_viterbi("Hauptbahnhof")
